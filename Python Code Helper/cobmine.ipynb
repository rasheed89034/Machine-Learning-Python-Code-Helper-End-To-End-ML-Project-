# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.read_csv('Q&A.csv',encoding='latin1', on_bad_lines='warn')

# %%
df1.head()
# Out:
#                           Question  \
# 0                  What is Python?
# 1              Who created Python?
# 2  When was Python first released?
# 3                  Is Python free?
# 4         What does 'Python' mean?
#
#                                             Answer
# 0  A high-level, interpreted programming language.
# 1                                Guido van Rossum.
# 2                                             1991
# 3                           Yes, it's open-source.
# 4    Named after 'Monty Python??s Flying Circus'.

# %%
df2 = pd.read_csv('Python_codes.csv',encoding='latin1', on_bad_lines='warn')

# %%
df2.head()
# Out:
#                                             question  \
# 0  Create an array of length 5 which contains all...
# 1  Formulate an equation to calculate the height ...
# 2  Write a replace method for a string class whic...
# 3  Create an array of length 15 containing number...
# 4  Write a function to find the number of distinc...
#
#                                                 code
# 0                             arr = [2, 4, 6, 8, 10]
# 1  Height of triangle = opposite side length * si...
# 2  def replace(self, replace_with):\n    new_stri...
# 3  arr = [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33...
# 4  def find_num_distinct_states(matrix):\n    sta...

# %%
df2 = df2.rename(columns={'question':'Question','code':'Answer'})

# %%
df = pd.concat([df1,df2],ignore_index=True)

# %%
df.head()
# Out:
#                           Question  \
# 0                  What is Python?
# 1              Who created Python?
# 2  When was Python first released?
# 3                  Is Python free?
# 4         What does 'Python' mean?
#
#                                             Answer
# 0  A high-level, interpreted programming language.
# 1                                Guido van Rossum.
# 2                                             1991
# 3                           Yes, it's open-source.
# 4    Named after 'Monty Python??s Flying Circus'.

# %%
df.tail()
# Out:
#                                                 Question  \
# 13973     how to change [1,2,3,4] to '1234' using python
# 13974        Delete every non utf-8 symbols froms string
# 13975  How to execute a command in the terminal from ...
# 13976                 Python MySQL Parameterized Queries
# 13977      Convert a string to datetime object in python
#
#                                                   Answer
# 13973                          """""".join([1, 2, 3, 4])
# 13974  line = line.decode('utf-8', 'ignore').encode('...
# 13975                                 os.system(command)
# 13976  c.execute('SELECT * FROM foo WHERE bar = %s AN...
# 13977  dateobj = datetime.datetime.strptime(datestr, ...

# %%
df.to_csv('combineDataset.csv')
